# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn import linear_model
# %matplotlib inline

# %%
# Import listings.csv and load it as pandas dataframe
df_listings = pd.read_csv("listings.csv")

# %%
# Print out the head of the listings data
df_listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   8521   https://www.airbnb.com/rooms/8521  20210130031937   2021-01-30
# 1  11169  https://www.airbnb.com/rooms/11169  20210130031937   2021-01-31
# 2  11945  https://www.airbnb.com/rooms/11945  20210130031937   2021-01-31
# 3  19581  https://www.airbnb.com/rooms/19581  20210130031937   2021-01-31
# 4  22006  https://www.airbnb.com/rooms/22006  20210130031937   2021-01-31
#
#                                                name  \
# 0  SunsplashedSerenity walk to Harvard & Fresh Pond
# 1   Lovely Studio Room: Thu-Mons, Near Universities
# 2                  Near Harvard: Safe & Lovely Room
# 3                          Furnished suite, Windsor
# 4                  B & B near Harvard's Quad Houses
#
#                                          description  \
# 0  An elegant, sun-splashed, 2 bedroom (+2offices...
# 1  Large sunny room which comfortably fits a coup...
# 2  Room next to kitchen and living room in wonder...
# 3  Welcome to Area IV! We are located, convenient...
# 4  Your choice (depending on availability) of one...
#
#                                neighborhood_overview  \
# 0  Huron Village is known for its charm.  We have...
# 1  The neighborhood is quiet and friendly and our...
# 2  Amazing neighborhood: Quiet yet close walk to ...
# 3                                                NaN
# 4  We're in a beautiful neighborhood, with nearby...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/30536/072e0a5...   306681
# 1  https://a0.muscache.com/pictures/75383179/7e2a...    40965
# 2  https://a0.muscache.com/pictures/88bf993e-1956...    40965
# 3  https://a0.muscache.com/pictures/188f1b4b-f37b...    74249
# 4  https://a0.muscache.com/pictures/10277743/5814...    84280
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/306681  ...                        10.0
# 1   https://www.airbnb.com/users/show/40965  ...                        10.0
# 2   https://www.airbnb.com/users/show/40965  ...                        10.0
# 3   https://www.airbnb.com/users/show/74249  ...                        10.0
# 4   https://www.airbnb.com/users/show/84280  ...                        10.0
#
#   review_scores_location review_scores_value      license instant_bookable  \
# 0                   10.0                 9.0  C0121120491                t
# 1                   10.0                10.0          NaN                f
# 2                   10.0                10.0          NaN                f
# 3                   10.0                 8.0          NaN                f
# 4                   10.0                10.0    STR-13676                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              2                                           2
# 1                              3                                           0
# 2                              3                                           0
# 3                              3                                           0
# 4                              1                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            3
# 3                                            3
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.26
# 1                                           0              1.10
# 2                                           0              0.25
# 3                                           0              0.05
# 4                                           0              0.81
#
# [5 rows x 74 columns]

# %%
# List out all the columns in the listings
list(df_listings.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'number_of_reviews_l30d',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'license',
#  'instant_bookable',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
# Check correlation matrix
corr = df_listings.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(20, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw a heatmap 
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .70})
# Out:
# <AxesSubplot:>

# %%
# Remove unwanted characters and convet into float
df_listings.price = df_listings.price.replace('[\$,]', '', regex=True).astype(float)

# %%
# Convert columns into datetime
df_listings['host_since'] = pd.to_datetime(df_listings['host_since'])

# %%
# Group the data by the column 'host_since'
result = df_listings.groupby(df_listings['host_since'].map(lambda x: x.year)).id.count()
year = pd.DataFrame(result)

# %%
# Rename the 'id' column to listings
year.rename(columns={'id':'listings'}, inplace=True)
year = pd.DataFrame(year).reset_index()

# %%
# Create a column with cumsum of the listings by year
year['total listings']= year['listings'].cumsum(axis=0)

# %%
# Convert'host_since' to int
year['host_since'] = year['host_since'].astype(int)
# Remnaming the column 'Host_Since' to 'year'
year.rename(columns={'host_since':'year'}, inplace=True)

# %%
#Cambridge,MA Airbnb listings over year
sns.set(style="darkgrid")
fig, ax = plt.subplots()
ax = sns.barplot(x="year", y="total listings", data=year, color='Coral')
ax.set_title('Airbnb Listings in Cambridge')
# Out:
# Text(0.5, 1.0, 'Airbnb Listings in Cambridge')

# %%
#New Airbnb Listings in Cambridge, MA
sns.set(style="darkgrid")
fig, ax = plt.subplots()
ax = sns.barplot(x='year', y="listings", data=year, color="coral")
ax.set_title('New Airbnb Listings in Cambridge')
# Out:
# Text(0.5, 1.0, 'New Airbnb Listings in Cambridge')

# %%
#Room Type in Cambridge, MA
sns.set(style="darkgrid")
fig, ax = plt.subplots()
# Title
ax.axes.set_title("Room Type in Cambridge, MA")
# Countplot for 'room_type' and their count
ax = sns.countplot(y='room_type',data=df_listings,order=df_listings['room_type'].value_counts().index, palette="Set3")
# X and Y Lables
ax.set_xlabel('Number of Listings')
ax.set_ylabel('Room Type')
# Out:
# Text(0, 0.5, 'Room Type')

# %%
#Top neighbourhoods in Cambridge, MA
sns.set(style="darkgrid")
fig, ax = plt.subplots()

ax.axes.set_title("Top neighbourhoods in Cambridge, MA")
# Countplot for 'neighbourhood' and their count
ax = sns.countplot(y='neighbourhood',data=df_listings, order = df_listings['neighbourhood'].value_counts().iloc[:20].index, palette="Set3")
# X and Y labels
ax.set_xlabel('Number of Listings')
ax.set_ylabel('Neighbourhood')
# Out:
# Text(0, 0.5, 'Neighbourhood')

# %%
#load calendar data
calendar = pd.read_csv("calendar.csv")
calendar.head(10)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0        8521  2021-01-30         f  $150.00        $150.00             3.0
# 1        8521  2021-01-31         f  $150.00        $150.00             3.0
# 2        8521  2021-02-01         f  $150.00        $150.00             3.0
# 3        8521  2021-02-02         f  $150.00        $150.00             3.0
# 4        8521  2021-02-03         f  $150.00        $150.00             3.0
# 5        8521  2021-02-04         f  $150.00        $150.00             3.0
# 6        8521  2021-02-05         f  $150.00        $150.00             3.0
# 7        8521  2021-02-06         f  $150.00        $150.00             3.0
# 8        8521  2021-02-07         f  $150.00        $150.00             3.0
# 9        8521  2021-02-08         f  $150.00        $150.00             3.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0
# 5          1125.0
# 6          1125.0
# 7          1125.0
# 8          1125.0
# 9          1125.0

# %%
#Print columns information 
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292031 entries, 0 to 292030
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   listing_id      292031 non-null  int64
#  1   date            292031 non-null  object
#  2   available       292031 non-null  object
#  3   price           292031 non-null  object
#  4   adjusted_price  292031 non-null  object
#  5   minimum_nights  292000 non-null  float64
#  6   maximum_nights  292000 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 15.6+ MB

# %%
#Remove $ sign on the price column and convert to numeric value
calendar['price'] =calendar['price'].apply(lambda x: str(x).replace('$',''))
calendar['price'] = pd.to_numeric(calendar['price'], errors = 'coerce')
df_calendar = calendar.groupby('date')[["price"]].sum()
df_calendar['mean'] = calendar.groupby('date')[["price"]].mean()
df_calendar.columns = ['Total Price', 'Avg Price']
df_calendar.head(10)
# Out:
#             Total Price   Avg Price
# date
# 2021-01-30      87529.0  142.787928
# 2021-01-31     105616.0  132.185232
# 2021-02-01     106598.0  133.414268
# 2021-02-02     106816.0  133.687109
# 2021-02-03     106708.0  133.551940
# 2021-02-04     106669.0  133.503129
# 2021-02-05     108449.0  135.730914
# 2021-02-06     108726.0  136.077597
# 2021-02-07     106797.0  133.663329
# 2021-02-08     106910.0  133.804756

# %%
#Set date as index
df_calendar2 = calendar.set_index("date")
df_calendar2.index = pd.to_datetime(df_calendar2.index)
df_calendar2 = df_calendar2[['price']].resample('M').mean()
df_calendar2.head(10)
# Out:
#                  price
# date
# 2021-01-31  136.788244
# 2021-02-28  135.266002
# 2021-03-31  149.640680
# 2021-04-30  152.898748
# 2021-05-31  157.407389
# 2021-06-30  161.039365
# 2021-07-31  161.240006
# 2021-08-31  159.261173
# 2021-09-30  158.875344
# 2021-10-31  158.582462

# %%
#Summary statistics
print(df_calendar2.describe())
# Out:
#             price
# count   13.000000
# mean   153.392710
# std      8.431244
# min    135.266002
# 25%    152.898748
# 50%    155.841844
# 75%    158.875344
# max    161.240006

# %%
# Price by Month Line Chart
ax=df_calendar2.plot(figsize=(12,5), color='blue')
ax.set_title('Price by Month')
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.show()
